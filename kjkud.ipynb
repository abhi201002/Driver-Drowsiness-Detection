# %%
import cv2
import matplotlib.pyplot as mp

# %%
w = cv2.imread('train/Closed_Eyes')
w = cv2.cvtColor(w,cv2.COLOR_BGR2RGB)
mp.imshow(w)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 w = cv2.imread('train/Closed_Eyes')
# ----> 2 w = cv2.cvtColor(w,cv2.COLOR_BGR2RGB)
#       3 mp.imshow(w)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
from os import listdir

# %%
directory = r'C:\Users\pgupt\Documents\DSP Project\train\Closed_Eyes'

x = [cv2.imread(directory + '/' + images) for images in os.listdir(directory)]

mp.imshow(x[3])

# %%
x
# Out:
# [array([[[38, 38, 38],
#          [41, 41, 41],
#          [44, 44, 44],
#          ...,
#          [89, 89, 89],
#          [89, 89, 89],
#          [89, 89, 89]],
#
#         [[38, 38, 38],
#          [41, 41, 41],
#          [44, 44, 44],
#          ...,
#          [92, 92, 92],
#          [92, 92, 92],
#          [91, 91, 91]],
#
#         [[38, 38, 38],
#          [41, 41, 41],
#          [43, 43, 43],
#          ...,
#          [94, 94, 94],
#          [93, 93, 93],
#          [93, 93, 93]],
#
#         ...,
#
#         [[52, 52, 52],
#          [54, 54, 54],
#          [60, 60, 60],
#          ...,
#          [78, 78, 78],
#          [78, 78, 78],
#          [80, 80, 80]],
#
#         [[51, 51, 51],
#          [53, 53, 53],
#          [59, 59, 59],
#          ...,
#          [81, 81, 81],
#          [81, 81, 81],
#          [81, 81, 81]],
#
#         [[51, 51, 51],
#          [51, 51, 51],
#          [55, 55, 55],
#          ...,
#          [80, 80, 80],
# ...

# %%
import pandas as pd

# %%
for i in enumerate(x):
    x[i] = pd.DataFrame(x[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
#       1 for i in enumerate(x):
# ----> 2     x[i] = pd.DataFrame(x[i])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
x[0][1]
# Out:
# array([[[89, 89, 89],
#         [88, 88, 88],
#         [91, 91, 91],
#         ...,
#         [51, 51, 51],
#         [51, 51, 51],
#         [51, 51, 51]],
#
#        [[91, 91, 91],
#         [90, 90, 90],
#         [90, 90, 90],
#         ...,
#         [50, 50, 50],
#         [50, 50, 50],
#         [51, 51, 51]],
#
#        [[91, 91, 91],
#         [88, 88, 88],
#         [89, 89, 89],
#         ...,
#         [50, 50, 50],
#         [50, 50, 50],
#         [50, 50, 50]],
#
#        ...,
#
#        [[66, 66, 66],
#         [64, 64, 64],
#         [64, 64, 64],
#         ...,
#         [66, 66, 66],
#         [64, 64, 64],
#         [62, 62, 62]],
#
#        [[68, 68, 68],
#         [65, 65, 65],
#         [63, 63, 63],
#         ...,
#         [65, 65, 65],
#         [66, 66, 66],
#         [64, 64, 64]],
#
#        [[67, 67, 67],
#         [65, 65, 65],
#         [63, 63, 63],
#         ...,
#         [63, 63, 63],
#         [63, 63, 63],
#         [63, 63, 63]]], dtype=uint8)

# %%
mp.imshow(x[0][1])

# %%
import numpy as np

# %%
value = np.asarray(x[0][1], dtype=np.int)
value = value.flatten()
# Out:
# C:\Users\pgupt\AppData\Local\Temp\ipykernel_10536\1106606960.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   value = np.asarray(x[0][1], dtype=np.int)

# %%
value
# Out:
# array([89, 89, 89, ..., 63, 63, 63])

# %%
mp.imshow(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 mp.imshow(value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# ...
